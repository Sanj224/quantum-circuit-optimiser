# %% [markdown]
# In this notebook,we will be using pyzx to convert circuits into a x diagram, and apply various rules to optimise and simplify the circuit.

# %%
import qiskit
from qiskit import QuantumCircuit
import pyzx
from quantum_optimiser import integration



#Create a basic circuit
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)

diagram = integration.qiskitToPyZX(qc)
print(diagram)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 from qiskit import QuantumCircuit
#       3 import pyzx
# ----> 4 from quantum_optimiser import qiskitToPyZX
#       8 #Create a basic circuit
#       9 qc = QuantumCircuit(2)
#
# ImportError: cannot import name 'qiskitToPyZX' from 'quantum_optimiser' (C:\Users\sanja\quantum-circuit-optimiser\src\quantum_optimiser\__init__.py)
