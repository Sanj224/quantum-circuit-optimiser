# %% [markdown]
# In this notebook,we will be using pyzx to convert circuits into a x diagram, and apply various rules to optimise and simplify the circuit.

# %%
import qiskit
from qiskit import QuantumCircuit
import pyzx
from quantum-optimiser import qiskitToPyZX



#Create a basic circuit
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)

diagram = qiskitToPyZX(qc)
print(diagram)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 10
#       7 qc.h(0)
#       8 qc.cx(0,1)
# ---> 10 qasm_str = qc.qasm(formatted=True)
#      11 with open("my_circuit.qasm", "w") as f:
#      12     f.write(qasm_str)
#
# AttributeError: 'QuantumCircuit' object has no attribute 'qasm'
