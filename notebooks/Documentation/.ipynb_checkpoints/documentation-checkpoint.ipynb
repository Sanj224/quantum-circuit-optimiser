# %% [markdown]
# # Documentation

# %% [markdown]
# ## Converting from a qiskit circuit to a pyzx diagram and vice versa

# %%
# %load_ext autoreload
# %autoreload 2
#Get jupyter to display more then one diagrams 
from IPython.display import display
# Make sure you're using the right magic
# %matplotlib inline  
# or %matplotlib widget

import pyzx

import qiskit
from qiskit import QuantumCircuit
import pyzx    
from quantum_optimiser import integration
from quantum_optimiser.multimetric import metrics
from quantum_optimiser.multimetric import loss
from quantum_optimiser.multimetric import rewrite
from quantum_optimiser.multimetric import simulated_annealing
   
## Create a very inefficient Quantum Circuit
qc = QuantumCircuit(2)
qc.s(0)
qc.sdg(0)
qc.h(0)
qc.h(0)
qc.h(0)     
qc.sdg(0)
qc.s(0)
qc.x(0)
qc.x(0)     
qc.z(0)
qc.z(0)    

qc.cx(0,1)

qc.s(1)
qc.sdg(1)
qc.draw("mpl")


qc2 = QuantumCircuit(2)
qc2.h(0)
qc2.cx(0,1)
qc2.draw("mpl")


diagram = integration.qiskit_to_pyzx(qc)
#pyzx.draw(diagram)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(metrics.circuit_qubit_count(qc))
print(metrics.circuit_gate_count(qc))
print(metrics.circuit_t_gate_count(qc))


print(metrics.graph_qubit_count(diagram))
print(metrics.graph_gate_count(diagram))
print(metrics.graph_t_gate_count(diagram))
print(metrics.graph_clifford_gate_count(diagram))


integration.pyzx_to_qiskit(diagram)
qc.draw("mpl")
# Out:
# 2
# 14
# 0
# 2
# 15
# 0
# 18

# %%
print(loss.naive_loss(qc))
print(loss.informed_loss(qc))

print(loss.naive_loss(qc2))
print(loss.informed_loss(qc2))
# Out:
# 6.200000000000001
# 3.2
# 1.4
# 0.8

# %%
pyzx.draw(diagram,labels="true")
vertices = (list(diagram.vertices()))
#for i in vertices:
    #print(i)
    #print(rewrite.get_applicable_rules(diagram,i))

new = rewrite.try_fuse(diagram, 6)

print(rewrite.get_applicable_rules(diagram,3))
# Out:
# ['color_change', 'fuse_with_2']

# %%
from pyzx import basicrules as br
pyzx.draw(diagram, labels = "true")
pyzx.draw(new,labels="true")
circ = integration.pyzx_to_qiskit(new)
circ.draw("mpl")

# %%
best_diagram, best_cost, history = simulated_annealing.simulated_annealing_zx(
    diagram=diagram,
    cost_function=loss.informed_loss_diagram,
    get_neighbor=simulated_annealing.get_neighbor_random_vertex_random_rule,
    initial_temp=100.0,
    cooling_rate=0.95,
    max_iterations=500
)

pyzx.draw(diagram, labels="true")
pyzx.draw(best_diagram, labels = "true")
print(integration.can_convert_to_circuit(best_diagram))
circ = integration.pyzx_to_qiskit(best_diagram)
circ.draw("mpl")
# Out:
# True

# %%
from qiskit.circuit.random import random_clifford_circuit
from qiskit.circuit.random import random_circuit
from qiskit import transpile

from qiskit import QuantumCircuit
import random

def random_clifford_t_circuit_controlled(num_qubits, depth, t_probability=0.2):
    """
    Generate random circuit with controlled T-gate density
    
    Args:
        num_qubits: Number of qubits
        depth: Circuit depth
        t_probability: Probability of T/Tdg gates vs Clifford gates
    """
    circ = QuantumCircuit(num_qubits)
    
    clifford_single = ['h', 'x', 'y', 'z', 's', 'sdg']
    t_gates = ['t', 'tdg']
    two_qubit_clifford = ['cx', 'cz', 'cy', 'swap']
    for _ in range(depth):
        if random.random() < 0.4 and num_qubits > 1:  # Two-qubit gate
            q1, q2 = random.sample(range(num_qubits), 2)
            gate = random.choice(two_qubit_clifford)
            getattr(circ, gate)(q1, q2)
        else:  # Single-qubit gate
            qubit = random.randint(0, num_qubits - 1)
            if random.random() < t_probability:
                gate = random.choice(t_gates)
            else:
                gate = random.choice(clifford_single)
            getattr(circ, gate)(qubit)
    
    return circ

# Generate circuit
circ = random_clifford_t_circuit_controlled(5, 20, t_probability=0.25)
circ.draw("mpl")
print(loss.quadratic_loss_circuit(circ))
# Out:
# 3.885

# %%
new_diagram = integration.qiskit_to_pyzx(circ)
fig =pyzx.draw(new_diagram)
display(fig)

function = loss.cost_function_from_circuit(loss.quadratic_loss_circuit)
best_diagram, best_cost, history = simulated_annealing.simulated_annealing_zx(
    diagram=new_diagram,
    cost_function=function,
    get_neighbor=simulated_annealing.get_neighbor_greedy,
    initial_temp=100.0,
    cooling_rate=0.95,
    max_iterations=500,
    verbose = False
)
# Out:
# Cost evaluation 50: cost=3.98
# Cost evaluation 100: cost=3.65
# Cost evaluation 150: cost=3.50
# Cost evaluation 200: cost=3.50
# Cost evaluation 250: cost=3.50
# Cost evaluation 300: cost=3.50
# Cost evaluation 350: cost=3.46
# Cost evaluation 400: cost=3.46
# Cost evaluation 450: cost=3.49
# Cost evaluation 500: cost=3.57
# Cost evaluation 550: cost=3.49
# Cost evaluation 600: cost=3.46
# Cost evaluation 650: cost=3.49
# Cost evaluation 700: cost=3.57
# Cost evaluation 750: cost=3.49
# Cost evaluation 800: cost=3.46
# Cost evaluation 850: cost=3.49
# Cost evaluation 900: cost=3.57
# Cost evaluation 950: cost=3.49
# Cost evaluation 1000: cost=3.46
# Cost evaluation 1050: cost=3.49
# Cost evaluation 1100: cost=3.57
# Cost evaluation 1150: cost=3.49
# Cost evaluation 1200: cost=3.46
# Cost evaluation 1250: cost=3.49
# Cost evaluation 1300: cost=3.57
# Cost evaluation 1350: cost=3.49
# Cost evaluation 1400: cost=3.46
# Cost evaluation 1450: cost=3.49
# Cost evaluation 1500: cost=3.57
# Cost evaluation 1550: cost=3.49
# Cost evaluation 1600: cost=3.46
# Cost evaluation 1650: cost=3.49
# Cost evaluation 1700: cost=3.57
# Cost evaluation 1750: cost=3.49
# Cost evaluation 1800: cost=3.46
# Cost evaluation 1850: cost=3.49
# Cost evaluation 1900: cost=3.57
# Cost evaluation 1950: cost=3.49
# Cost evaluation 2000: cost=3.46
# Cost evaluation 2050: cost=3.49
# Cost evaluation 2100: cost=3.57
# Cost evaluation 2150: cost=3.49
# Cost evaluation 2200: cost=3.46
# Cost evaluation 2250: cost=3.49
# Cost evaluation 2300: cost=3.57
# Cost evaluation 2350: cost=3.49

# %%
newfig = pyzx.draw(best_diagram, labels = True)
display(newfig)

# %%
circ2 = integration.pyzx_to_qiskit(best_diagram)
circ2.draw("mpl")

# %%
print(loss.naive_loss(circ2))
# Out:
# 10.4

# %%
# Out:
# === DIAGNOSTIC INFO ===
# PyZX version: 0.9.0
# Mode: notebook
# Backend: matplotlib
# Diagram type: <class 'pyzx.graph.graph_s.GraphS'>
# Vertices: 24
# Edges: 26
# Diagram: Graph(24 vertices, 26 edges)
#
# === ATTEMPTING TO DRAW ===
# Draw returned: Figure(800x200)
# Figure type: <class 'matplotlib.figure.Figure'>
#
# === TRYING TO SAVE TO FILE ===
# Saved to diagram_test.png

# %%
# Out:
# Circuit 1/10... Cost evaluation 50: cost=14.80
# Cost evaluation 100: cost=15.40
# Cost evaluation 150: cost=11.20
# Cost evaluation 50: cost=9.60
# Cost evaluation 100: cost=8.70
# Cost evaluation 150: cost=6.50
# Cost evaluation 50: cost=4.68
# Cost evaluation 100: cost=5.16
# Cost evaluation 150: cost=4.67
# Done
# Circuit 2/10... Cost evaluation 50: cost=9.80
# Cost evaluation 100: cost=8.00
# Cost evaluation 150: cost=7.40
# Cost evaluation 50: cost=5.90
# Cost evaluation 100: cost=5.60
# Cost evaluation 150: cost=5.40
# Cost evaluation 50: cost=3.12
# Cost evaluation 100: cost=2.58
# Cost evaluation 150: cost=2.71
# Done
# Circuit 3/10... Cost evaluation 50: cost=11.20
# Cost evaluation 100: cost=10.40
# Cost evaluation 150: cost=7.20
# Cost evaluation 50: cost=6.10
# Cost evaluation 100: cost=6.60
# Cost evaluation 150: cost=4.60
# Cost evaluation 50: cost=3.07
# Cost evaluation 100: cost=3.06
# Cost evaluation 150: cost=2.51
# Done
# Circuit 4/10... Cost evaluation 50: cost=9.60
# Cost evaluation 100: cost=7.20
# Cost evaluation 150: cost=7.20
# Cost evaluation 50: cost=5.50
# Cost evaluation 100: cost=5.50
# Cost evaluation 150: cost=4.30
# Cost evaluation 50: cost=1.95
# Cost evaluation 100: cost=1.82
# Cost evaluation 150: cost=1.91
# Done
# Circuit 5/10... Cost evaluation 50: cost=10.60
# Cost evaluation 100: cost=10.20
# Cost evaluation 150: cost=8.00
# Cost evaluation 50: cost=6.00
# Cost evaluation 100: cost=6.70
# Cost evaluation 150: cost=5.50
# Cost evaluation 50: cost=4.04
# Cost evaluation 100: cost=3.56
# Cost evaluation 150: cost=3.52
# Done
# Circuit 6/10... Cost evaluation 50: cost=13.00
# Cost evaluation 100: cost=9.00
# Cost evaluation 150: cost=8.20
# Cost evaluation 50: cost=7.90
# Cost evaluation 100: cost=5.60
# Cost evaluation 150: cost=4.40
# Cost evaluation 50: cost=2.08
# Cost evaluation 100: cost=1.90
# Cost evaluation 150: cost=2.38
# Done
# Circuit 7/10... Cost evaluation 50: cost=12.00
# Cost evaluation 100: cost=10.20
# Cost evaluation 150: cost=8.40
# Cost evaluation 50: cost=5.80
# Cost evaluation 100: cost=5.60
# Cost evaluation 150: cost=5.10
# Cost evaluation 50: cost=3.58
# Cost evaluation 100: cost=3.58
# Cost evaluation 150: cost=3.57
# Done
# Circuit 8/10... Cost evaluation 50: cost=11.80
# Cost evaluation 100: cost=10.80
# Cost evaluation 150: cost=9.60
# Cost evaluation 50: cost=9.00
# Cost evaluation 100: cost=6.20
# Cost evaluation 150: cost=5.50
# Cost evaluation 50: cost=4.02
# Cost evaluation 100: cost=3.98
# Cost evaluation 150: cost=3.50
# Done
# Circuit 9/10... Cost evaluation 50: cost=13.20
# Cost evaluation 100: cost=12.80
# Cost evaluation 150: cost=11.40
# Cost evaluation 50: cost=8.90
# Cost evaluation 100: cost=8.50
# Cost evaluation 150: cost=6.60
# Cost evaluation 50: cost=4.13
# Cost evaluation 100: cost=3.71
# Cost evaluation 150: cost=3.52
# Done
# Circuit 10/10... Cost evaluation 50: cost=10.00
# Cost evaluation 100: cost=9.40
# Cost evaluation 150: cost=6.40
# Cost evaluation 50: cost=6.70
# Cost evaluation 100: cost=4.90
# Cost evaluation 150: cost=3.80
# Cost evaluation 50: cost=2.68
# Cost evaluation 100: cost=2.58
# Cost evaluation 150: cost=2.68
# Done
#
# ==================================================
# AVERAGE IMPROVEMENT PER LOSS FUNCTION
# ==================================================
# naive_loss          :  1.340 ±  0.895
# informed_loss       :  1.840 ±  0.755
# quadratic_loss      :  1.488 ±  0.968

# %%
# Out:
# [autoreload of quantum_optimiser.multimetric.simulated_annealing failed: Traceback (most recent call last):
#   File "C:\Users\sanja\quantum-circuit-optimiser\venv\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\sanja\quantum-circuit-optimiser\venv\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "C:\Users\sanja\quantum-circuit-optimiser\src\quantum_optimiser\multimetric\simulated_annealing.py", line 125
#     print(f"Original cost:" initial_cost)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
# ]
# Circuit 1/10... Cost evaluation 50: cost=0.61
# Cost evaluation 100: cost=0.62
# Cost evaluation 150: cost=0.61
# Cost evaluation 200: cost=0.62
# Cost evaluation 250: cost=0.59
# Cost evaluation 300: cost=0.56
# Cost evaluation 350: cost=0.65
# Cost evaluation 400: cost=0.60
# Cost evaluation 450: cost=0.56
# Cost evaluation 500: cost=0.61
# Cost evaluation 50: cost=0.41
# Cost evaluation 100: cost=0.44
# Cost evaluation 150: cost=0.51
# Cost evaluation 200: cost=0.50
# Cost evaluation 250: cost=0.43
# Cost evaluation 300: cost=0.36
# Cost evaluation 350: cost=0.34
# Cost evaluation 400: cost=0.59
# Cost evaluation 450: cost=0.52
# Cost evaluation 500: cost=0.52
# Cost evaluation 50: cost=6.34
# Cost evaluation 100: cost=5.78
# Cost evaluation 150: cost=5.38
# Cost evaluation 200: cost=5.45
# Cost evaluation 250: cost=6.19
# Cost evaluation 300: cost=6.25
# Cost evaluation 350: cost=5.20
# Cost evaluation 400: cost=5.33
# Cost evaluation 450: cost=5.27
# Cost evaluation 500: cost=5.21
# Done
# Circuit 2/10... Cost evaluation 50: cost=0.72
# Cost evaluation 100: cost=0.74
# Cost evaluation 150: cost=0.78
# Cost evaluation 200: cost=0.72
# Cost evaluation 250: cost=0.70
# Cost evaluation 300: cost=0.79
# Cost evaluation 350: cost=0.74
# Cost evaluation 400: cost=0.72
# Cost evaluation 450: cost=0.73
# Cost evaluation 500: cost=0.75
# Cost evaluation 50: cost=0.65
# Cost evaluation 100: cost=0.74
# Cost evaluation 150: cost=0.82
# Cost evaluation 200: cost=0.51
# Cost evaluation 250: cost=0.58
# Cost evaluation 300: cost=0.58
# Cost evaluation 350: cost=0.66
# Cost evaluation 400: cost=0.66
# Cost evaluation 450: cost=0.65
# Cost evaluation 500: cost=0.74
# Cost evaluation 50: cost=14.25
# Cost evaluation 100: cost=14.06
# Cost evaluation 150: cost=14.76
# Cost evaluation 200: cost=14.92
# Cost evaluation 250: cost=13.98
# Cost evaluation 300: cost=13.90
# Cost evaluation 350: cost=14.22
# Cost evaluation 400: cost=14.87
# Cost evaluation 450: cost=14.10
# Cost evaluation 500: cost=13.76
# Done
# Circuit 3/10... Cost evaluation 50: cost=0.58
# Cost evaluation 100: cost=0.54
# Cost evaluation 150: cost=0.60
# Cost evaluation 200: cost=0.59
# Cost evaluation 250: cost=0.52
# Cost evaluation 300: cost=0.58
# Cost evaluation 350: cost=0.50
# Cost evaluation 400: cost=0.56
# Cost evaluation 450: cost=0.53
# Cost evaluation 500: cost=0.50
# Cost evaluation 50: cost=0.56
# Cost evaluation 100: cost=0.47
# Cost evaluation 150: cost=0.56
# Cost evaluation 200: cost=0.55
# Cost evaluation 250: cost=0.47
# Cost evaluation 300: cost=0.56
# Cost evaluation 350: cost=0.39
# Cost evaluation 400: cost=0.55
# Cost evaluation 450: cost=0.30
# Cost evaluation 500: cost=0.31
# Cost evaluation 50: cost=5.96
# Cost evaluation 100: cost=5.97
# Cost evaluation 150: cost=4.54
# Cost evaluation 200: cost=4.44
# Cost evaluation 250: cost=4.14
# Cost evaluation 300: cost=4.16
# Cost evaluation 350: cost=3.90
# Cost evaluation 400: cost=4.13
# Cost evaluation 450: cost=4.26
# Cost evaluation 500: cost=4.07
# Done
# Circuit 4/10... Cost evaluation 50: cost=0.56
# Cost evaluation 100: cost=0.56
# Cost evaluation 150: cost=0.53
# Cost evaluation 200: cost=0.51
# Cost evaluation 250: cost=0.53
# Cost evaluation 300: cost=0.53
# Cost evaluation 350: cost=0.48
# Cost evaluation 400: cost=0.51
# Cost evaluation 450: cost=0.53
# Cost evaluation 500: cost=0.50
# Cost evaluation 50: cost=0.42
# Cost evaluation 100: cost=0.50
# Cost evaluation 150: cost=0.34
# Cost evaluation 200: cost=0.33
# Cost evaluation 250: cost=0.41
# Cost evaluation 300: cost=0.41
# Cost evaluation 350: cost=0.34
# Cost evaluation 400: cost=0.33
# Cost evaluation 450: cost=0.34
# Cost evaluation 500: cost=0.34
# Cost evaluation 50: cost=6.00
# Cost evaluation 100: cost=5.78
# Cost evaluation 150: cost=5.87
# Cost evaluation 200: cost=5.95
# Cost evaluation 250: cost=5.84
# Cost evaluation 300: cost=5.79
# Cost evaluation 350: cost=5.91
# Cost evaluation 400: cost=5.95
# Cost evaluation 450: cost=5.69
# Cost evaluation 500: cost=5.82
# Done
# Circuit 5/10... Cost evaluation 50: cost=0.60
# Cost evaluation 100: cost=0.65
# Cost evaluation 150: cost=0.56
# Cost evaluation 200: cost=0.67
# Cost evaluation 250: cost=0.55
# Cost evaluation 300: cost=0.54
# Cost evaluation 350: cost=0.57
# Cost evaluation 400: cost=0.55
# Cost evaluation 450: cost=0.52
# Cost evaluation 500: cost=0.56
# Cost evaluation 50: cost=0.65
# Cost evaluation 100: cost=0.58
# Cost evaluation 150: cost=0.40
# Cost evaluation 200: cost=0.48
# Cost evaluation 250: cost=0.49
# Cost evaluation 300: cost=0.40
# Cost evaluation 350: cost=0.57
# Cost evaluation 400: cost=0.50
# Cost evaluation 450: cost=0.41
# Cost evaluation 500: cost=0.42
# Cost evaluation 50: cost=5.00
# Cost evaluation 100: cost=5.50
# Cost evaluation 150: cost=5.44
# Cost evaluation 200: cost=5.46
# Cost evaluation 250: cost=5.44
# Cost evaluation 300: cost=6.08
# Cost evaluation 350: cost=5.37
# Cost evaluation 400: cost=4.95
# Cost evaluation 450: cost=5.00
# Cost evaluation 500: cost=4.92
# Done
# Circuit 6/10... Cost evaluation 50: cost=0.61
# Cost evaluation 100: cost=0.60
# Cost evaluation 150: cost=0.59
# Cost evaluation 200: cost=0.61
# Cost evaluation 250: cost=0.51
# Cost evaluation 300: cost=0.61
# Cost evaluation 350: cost=0.58
# Cost evaluation 400: cost=0.52
# Cost evaluation 450: cost=0.59
# Cost evaluation 500: cost=0.53
# Cost evaluation 50: cost=0.58
# Cost evaluation 100: cost=0.49
# Cost evaluation 150: cost=0.65
# Cost evaluation 200: cost=0.58
# Cost evaluation 250: cost=0.56
# Cost evaluation 300: cost=0.64
# Cost evaluation 350: cost=0.57
# Cost evaluation 400: cost=0.49
# Cost evaluation 450: cost=0.56
# Cost evaluation 500: cost=0.40
# Cost evaluation 50: cost=6.94
# Cost evaluation 100: cost=5.50
# Cost evaluation 150: cost=5.50
# Cost evaluation 200: cost=6.95
# Cost evaluation 250: cost=6.90
# Cost evaluation 300: cost=5.33
# Cost evaluation 350: cost=5.36
# Cost evaluation 400: cost=5.46
# Cost evaluation 450: cost=5.06
# Cost evaluation 500: cost=5.02
# Done
# Circuit 7/10... Cost evaluation 50: cost=0.75
# Cost evaluation 100: cost=0.77
# Cost evaluation 150: cost=0.66
# Cost evaluation 200: cost=0.68
# Cost evaluation 250: cost=0.69
# Cost evaluation 300: cost=0.64
# Cost evaluation 350: cost=0.74
# Cost evaluation 400: cost=0.70
# Cost evaluation 450: cost=0.74
# Cost evaluation 500: cost=0.73
# Cost evaluation 50: cost=0.61
# Cost evaluation 100: cost=0.69
# Cost evaluation 150: cost=0.68
# Cost evaluation 200: cost=0.68
# Cost evaluation 250: cost=0.68
# Cost evaluation 300: cost=0.52
# Cost evaluation 350: cost=0.68
# Cost evaluation 400: cost=0.77
# Cost evaluation 450: cost=0.60
# Cost evaluation 500: cost=0.60
# Cost evaluation 50: cost=13.04
# Cost evaluation 100: cost=10.64
# Cost evaluation 150: cost=12.25
# Cost evaluation 200: cost=10.72
# Cost evaluation 250: cost=10.69
# Cost evaluation 300: cost=12.07
# Cost evaluation 350: cost=11.35
# Cost evaluation 400: cost=10.38
# Cost evaluation 450: cost=10.21
# Cost evaluation 500: cost=10.22
# Done
# Circuit 8/10... Cost evaluation 50: cost=0.60
# Cost evaluation 100: cost=0.62
# Cost evaluation 150: cost=0.64
# Cost evaluation 200: cost=0.60
# Cost evaluation 250: cost=0.62
# Cost evaluation 300: cost=0.60
# Cost evaluation 350: cost=0.60
# Cost evaluation 400: cost=0.63
# Cost evaluation 450: cost=0.57
# Cost evaluation 500: cost=0.54
# Cost evaluation 50: cost=0.61
# Cost evaluation 100: cost=0.47
# Cost evaluation 150: cost=0.53
# Cost evaluation 200: cost=0.35
# Cost evaluation 250: cost=0.70
# Cost evaluation 300: cost=0.60
# Cost evaluation 350: cost=0.44
# Cost evaluation 400: cost=0.51
# Cost evaluation 450: cost=0.43
# Cost evaluation 500: cost=0.36
# Cost evaluation 50: cost=7.17
# Cost evaluation 100: cost=6.65
# Cost evaluation 150: cost=6.55
# Cost evaluation 200: cost=7.21
# Cost evaluation 250: cost=6.08
# Cost evaluation 300: cost=6.43
# Cost evaluation 350: cost=6.44
# Cost evaluation 400: cost=6.41
# Cost evaluation 450: cost=6.23
# Cost evaluation 500: cost=5.92
# Done
# Circuit 9/10... Cost evaluation 50: cost=0.62
# Cost evaluation 100: cost=0.61
# Cost evaluation 150: cost=0.58
# Cost evaluation 200: cost=0.60
# Cost evaluation 250: cost=0.66
# Cost evaluation 300: cost=0.60
# Cost evaluation 350: cost=0.62
# Cost evaluation 400: cost=0.61
# Cost evaluation 450: cost=0.68
# Cost evaluation 500: cost=0.61
# Cost evaluation 50: cost=0.63
# Cost evaluation 100: cost=0.44
# Cost evaluation 150: cost=0.71
# Cost evaluation 200: cost=0.54
# Cost evaluation 250: cost=0.63
# Cost evaluation 300: cost=0.63
# Cost evaluation 350: cost=0.61
# Cost evaluation 400: cost=0.69
# Cost evaluation 450: cost=0.45
# Cost evaluation 500: cost=0.44
# Cost evaluation 50: cost=9.23
# Cost evaluation 100: cost=7.33
# Cost evaluation 150: cost=7.51
# Cost evaluation 200: cost=7.17
# Cost evaluation 250: cost=7.57
# Cost evaluation 300: cost=7.53
# Cost evaluation 350: cost=7.23
# Cost evaluation 400: cost=7.24
# Cost evaluation 450: cost=7.28
# Cost evaluation 500: cost=7.10
# Done
# Circuit 10/10... Cost evaluation 50: cost=0.74
# Cost evaluation 100: cost=0.75
# Cost evaluation 150: cost=0.71
# Cost evaluation 200: cost=0.72
# Cost evaluation 250: cost=0.76
# Cost evaluation 300: cost=0.76
# Cost evaluation 350: cost=0.72
# Cost evaluation 400: cost=0.74
# Cost evaluation 450: cost=0.76
# Cost evaluation 500: cost=0.69
# Cost evaluation 50: cost=0.51
# Cost evaluation 100: cost=0.58
# Cost evaluation 150: cost=0.67
# Cost evaluation 200: cost=0.75
# Cost evaluation 250: cost=0.67
# Cost evaluation 300: cost=0.58
# Cost evaluation 350: cost=0.58
# Cost evaluation 400: cost=0.50
# Cost evaluation 450: cost=0.74
# Cost evaluation 500: cost=0.66
# Cost evaluation 50: cost=14.39
# Cost evaluation 100: cost=14.03
# Cost evaluation 150: cost=14.07
# Cost evaluation 200: cost=15.07
# Cost evaluation 250: cost=14.34
# Cost evaluation 300: cost=14.05
# Cost evaluation 350: cost=14.38
# Cost evaluation 400: cost=14.05
# Cost evaluation 450: cost=14.05
# Cost evaluation 500: cost=14.01
# Done
#
# ======================================================================
# AVERAGE COST IMPROVEMENT PER LOSS FUNCTION
# ======================================================================
# naive_loss          :  0.113 ±  0.067
# informed_loss       :  0.406 ±  0.170
# quadratic_loss_circuit:  3.541 ±  2.622
#
# ======================================================================
# AVERAGE METRIC REDUCTIONS PER LOSS FUNCTION
# ======================================================================
#
# naive_loss:
# --------------------------------------------------
#   Qubit Count              :   0.60 ±   0.70
#   Circuit Depth            :  -1.50 ±   1.18
#   Gate Count               : -19.60 ±   5.93
#   Two-Qubit Gate Count     :   0.00 ±   0.00
#   T Gate Count             :   4.90 ±   1.91
#
# informed_loss:
# --------------------------------------------------
#   Qubit Count              :   0.60 ±   0.70
#   Circuit Depth            :  -1.50 ±   1.18
#   Gate Count               : -21.70 ±   6.48
#   Two-Qubit Gate Count     :   0.00 ±   0.00
#   T Gate Count             :   5.20 ±   2.10
#
# quadratic_loss_circuit:
# --------------------------------------------------
#   Qubit Count              :   0.60 ±   0.70
#   Circuit Depth            :  -0.60 ±   0.84
#   Gate Count               : -15.70 ±   6.29
#   Two-Qubit Gate Count     :   0.00 ±   0.00
#   T Gate Count             :   5.00 ±   2.26
#
# ======================================================================
# METRIC REDUCTION COMPARISON (AVERAGE ACROSS ALL CIRCUITS)
# ======================================================================
#                         Qubit Count  Circuit Depth  Gate Count  Two-Qubit Gate Count  T Gate Count
# loss_function
# informed_loss                   0.6           -1.5       -21.7                   0.0           5.2
# naive_loss                      0.6           -1.5       -19.6                   0.0           4.9
# quadratic_loss_circuit          0.6           -0.6       -15.7                   0.0           5.0
#
# ======================================================================
# BEST LOSS FUNCTION PER METRIC
# ======================================================================
# Qubit Count                   : informed_loss        (  0.60)
# Circuit Depth                 : quadratic_loss_circuit ( -0.60)
# Gate Count                    : quadratic_loss_circuit (-15.70)
# Two-Qubit Gate Count          : informed_loss        (  0.00)
# T Gate Count                  : informed_loss        (  5.20)
#
# ✓ Detailed results saved to 'detailed_metrics_benchmark.csv'
