# %%
# %load_ext autoreload
# %autoreload 2

from quantum_optimiser import integration
from quantum_optimiser.multimetric import metrics
from quantum_optimiser.hardware_aware import hardware_map
from qiskit import QuantumCircuit
from IPython.display import display
# %matplotlib inline  

qc1 = QuantumCircuit(5,0)
qc1.h(0)
qc1.x(1)
qc1.h(1)
qc1.cx(0,1)
qc1.cz(1,2)
qc1.cx(4,0)
qc1.cz(0,4)

qc1.draw("mpl")


qc2 = hardware_map.linkedHardware.make_compatible(qc1)
qc2.draw("mpl")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
